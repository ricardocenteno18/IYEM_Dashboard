# %%
import pandas as pd
import numpy as np

# %%
#read a xlsx file
df = pd.read_excel('Seguimiento_Beneficiarias_DE_IYEM.xlsx', sheet_name='Beneficiarios', header = None)
#ignore the first 3 rows
df = df.iloc[5:]
df.header = None
#set the first row as the header
df.columns = df.iloc[0]
#delete the first row
df = df.iloc[1:]
df.head()
# Out:
# c:\Users\ricar\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# 5  CURP PRIMER APELLIDO SEGUNDO APELLIDO NOMBRE(S) NOMBRE COMPLETO  \
# 6   NaN             NaN              NaN       NaN             NaN
# 7   NaN             NaN              NaN       NaN             NaN
# 8   NaN             NaN              NaN       NaN             NaN
# 9   NaN             NaN              NaN       NaN             NaN
# 10  NaN             NaN              NaN       NaN             NaN
#
# 5  FECHA DE NACIMIENTO EDAD         SEXO MAYAHABLANTE Regionalización  ...  \
# 6                  NaN    0  Seleccionar          NaN             NaN  ...
# 7                  NaN    0  Seleccionar          NaN             NaN  ...
# 8                  NaN    0  Seleccionar          NaN             NaN  ...
# 9                  NaN    0  Seleccionar          NaN             NaN  ...
# ...

# %%
#df.columns
# Out:
# Index(['CURP', 'PRIMER APELLIDO', 'SEGUNDO APELLIDO', 'NOMBRE(S)',
#        'NOMBRE COMPLETO', 'FECHA DE NACIMIENTO', 'EDAD', 'SEXO',
#        'MAYAHABLANTE', 'Regionalización', 'MUNICIPIO', 'LOCALIDAD', 'CALLE',
#        'NÚMERO', 'COLONIA | FRACCCIONAMIENTO', 'CÓDIGO POSTAL', '☎️ TELÉFONO',
#        '📱Celular', '📧 CORREO ELECTRÓNICO', 'ID PROYECTO', 'RAZÓN SOCIAL',
#        'NOMBRE COMERCIAL', 'ALTA ANTE EL SAT', 'RFC', 'TAMAÑO',
#        'ACTIVIDAD ECONÓMICA', 'DESCRIPCIÓN DEL PROYECTO', 'CLASIFICACIÓN',
#        'NOMBRE DEL PROGRAMA | SERVICIO | PROYECTO', 'AÑO DE ATENCIÓN',
#        'VALOR DE APOYO OTORGADO'],
#       dtype='object', name=5)

# %%
#df['MUNICIPIO']
# Out:
# 6        1. Abalá
# 7      2. Acanceh
# 8     Seleccionar
# 9     Seleccionar
# 10    Seleccionar
# 11    Seleccionar
# 12    Seleccionar
# 13    Seleccionar
# 14    Seleccionar
# 15    Seleccionar
# 16    Seleccionar
# 17    Seleccionar
# 18    Seleccionar
# 19    Seleccionar
# 20    Seleccionar
# 21    Seleccionar
# 22    Seleccionar
# 23    Seleccionar
# 24    Seleccionar
# 25    Seleccionar
# 26    Seleccionar
# 27    Seleccionar
# 28    Seleccionar
# 29    Seleccionar
# 30    Seleccionar
# 31    Seleccionar
# 32    Seleccionar
# 33    Seleccionar
# 34    Seleccionar
# 35    Seleccionar
# 36    Seleccionar
# 37    Seleccionar
# 38    Seleccionar
# 39    Seleccionar
# 40    Seleccionar
# 41    Seleccionar
# 42    Seleccionar
# 43    Seleccionar
# 44    Seleccionar
# 45    Seleccionar
# 46    Seleccionar
# 47    Seleccionar
# 48    Seleccionar
# 49    Seleccionar
# 50    Seleccionar
# 51    Seleccionar
# 52    Seleccionar
# 53    Seleccionar
# 54    Seleccionar
# 55    Seleccionar
# ...

# %%
from dash import dash, dcc, html 
import plotly.express as px
from dash.dependencies import Input, Output

# %%
#creating a dropdown list
dropdown_list = []
for i in df['MUNICIPIO']:
    dropdown_list.append({'label': i, 'value': i})

#Creating the app
app = dash.Dash()

colors = {
    'background': '#111111',
    'text': '#7FDBFF'
}

#Creating the layout
app.layout = html.Div(style={'backgroundColor': colors['background']}, children=[
    html.H1(
        children = 'Seguimiento de Beneficiarias de IYEM Dashboard',
    style = {'textAlign': 'center',
            'color': colors['text'], 'font-family': 'Helvetica', 'font-size': '40px'}), 
    html.Div(dcc.Dropdown(id='dropdown', style={'backgroundColor': colors['text']}, 
                options=dropdown_list,
                value='Select')),
    html.Div(dcc.Graph(id='map'), style={'color': colors['text']}),
])

#Creating the callback
@app.callback( 
    Output(component_id='map', component_property='figure'),
    Input(component_id='dropdown', component_property='value')
)
def update_graph(value):
    df1 = df[df['MUNICIPIO'] == value]
    fig = px.choropleth(df1, locations='MUNICIPIO',
                        #color='GDP ()',
                        hover_name='MUNICIPIO',
                        color_continuous_scale=px.colors.sequential.Plasma)
    return fig

#Running the app
if __name__ == '__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [07/Feb/2023 13:29:49] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 13:29:49] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 13:29:49] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 13:29:49] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 13:29:49] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2023 13:29:49] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -
# ...
